# %%
# !pip install gymnasium
# !pip install swig
# !pip install ale-py
# !pip install "gymnasium[atari]"
# !pip install "autorom[accept-rom-license]"
# !pip install -q ml-collections
# !pip install tensorboardX
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.4)
# Collecting swig
#   Downloading swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Downloading swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 39.2 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.4.1
# Requirement already satisfied: ale-py in /usr/local/lib/python3.12/dist-packages (0.11.2)
# Requirement already satisfied: numpy>1.20 in /usr/local/lib/python3.12/dist-packages (from ale-py) (2.0.2)
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (0.11.2)
# Collecting autorom[accept-rom-license]
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from autorom[accept-rom-license]) (8.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from autorom[accept-rom-license]) (2.32.4)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 11.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (2026.1.4)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=autorom_accept_rom_license-0.6.1-py3-none-any.whl size=446710 sha256=10ba7293d227d53e71f85a6bdf84b09b9fe94cf5a9accccd7c18278606dfa00b
#   Stored in directory: /root/.cache/pip/wheels/99/f1/ff/c6966c034a8259164bdc9deb4d1ea839f119474638100e6645
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 autorom-0.6.1
# Collecting tensorboardX
#   Downloading tensorboardx-2.6.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (26.0)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (5.29.5)
# Downloading tensorboardx-2.6.5-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.5

# %%
import os
import urllib.request
from urllib.error import HTTPError

# %%
# !rm -f configs.py dqn_types.py model.py replay_buffer.py trainer.py agent.py env_wrapper.py

# %%
base_url = "https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/main/"

def download_file_from_github(file_path: str, file_name: str):
    if not os.path.isfile(file_name):
        file_url = base_url + file_path
        print(f"Downloading {file_url}...")
        try:
            urllib.request.urlretrieve(file_url, file_name)
        except HTTPError as e:
            print("Something went wrong. Please try to download the file directly from the GitHub repository:\n", e)


file_paths = [
    'dqn_with_vanilla_replay_buffer/configs.py',
    'dqn_with_vanilla_replay_buffer/dqn_types.py',
    'dqn_with_vanilla_replay_buffer/model.py',
    'dqn_with_vanilla_replay_buffer/replay_buffer.py',
    'dqn_with_vanilla_replay_buffer/trainer.py',
    'dqn_with_vanilla_replay_buffer/agent.py',
    'dqn_with_vanilla_replay_buffer/env_wrapper.py',
]
file_names = [
    'configs.py',
    'dqn_types.py',
    'model.py',
    'replay_buffer.py',
    'trainer.py',
    'agent.py',
    'env_wrapper.py',
]

for file_path, file_name in zip(file_paths, file_names): 
    download_file_from_github(file_path, file_name)
# Out:
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/main/dqn_with_vanilla_replay_buffer/configs.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/main/dqn_with_vanilla_replay_buffer/dqn_types.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/main/dqn_with_vanilla_replay_buffer/model.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/main/dqn_with_vanilla_replay_buffer/replay_buffer.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/main/dqn_with_vanilla_replay_buffer/trainer.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/main/dqn_with_vanilla_replay_buffer/agent.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/main/dqn_with_vanilla_replay_buffer/env_wrapper.py...

# %%
from dqn_types import DQNConfig, TrainerConfig
from agent import Agent
from trainer import AgentTrainer
from env_wrapper import EnvWrapper
import jax

# %%
env = EnvWrapper()
dqn_config = DQNConfig()
trainer_config = TrainerConfig()

# Create the agent
agent = Agent(dqn_config)
agent_init_rng = jax.random.key(20)

dqn_state = agent.init(
    agent_init_rng, 
    trainer_config.obs_shape, 
    trainer_config.learning_rate
)

# Create the agent trainer
trainer_initial_rng = jax.random.key(18)
trainer = AgentTrainer(agent, trainer_config, trainer_initial_rng)
dqn_state = trainer.run_train_loop(env, dqn_state)
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Episode 50 started
# Episode 100 started
# Reward checking: Episode: 100, Total discounted reward: 0.0
# Episode 150 started
# Episode 200 started
# Reward checking: Episode: 200, Total discounted reward: 1.3247241096981648
# Episode 250 started
# Episode 300 started
# Reward checking: Episode: 300, Total discounted reward: 1.5252084711479954
# Episode 350 started
# Episode 400 started
# Reward checking: Episode: 400, Total discounted reward: 1.4082244246554074
# Episode 450 started
# Episode 500 started
# Reward checking: Episode: 500, Total discounted reward: 1.1982853164502623
# Episode 550 started
# Episode 600 started
# Reward checking: Episode: 600, Total discounted reward: 1.4855065874250892
# Episode 650 started
# Episode 700 started
# Reward checking: Episode: 700, Total discounted reward: 1.6209859024577393
# Episode 750 started
# Episode 800 started
# Reward checking: Episode: 800, Total discounted reward: 1.5119449647294096
# Episode 850 started
# Episode 900 started
# Reward checking: Episode: 900, Total discounted reward: 1.268571594861582
# Episode 950 started
# Episode 1000 started
# Reward checking: Episode: 1000, Total discounted reward: 1.9637948086717507
# Episode 1050 started
# Episode 1100 started
# Reward checking: Episode: 1100, Total discounted reward: 1.8872181393294658
# Episode 1150 started
# Episode 1200 started
# Reward checking: Episode: 1200, Total discounted reward: 0.6979577423224818
# Episode 1250 started
# Episode 1300 started
# Reward checking: Episode: 1300, Total discounted reward: 2.1898717614764736
# Episode 1350 started
# Episode 1400 started
# Reward checking: Episode: 1400, Total discounted reward: 1.9783762713042203
# Episode 1450 started
# Episode 1500 started
# Reward checking: Episode: 1500, Total discounted reward: 1.6692771658276526
# Episode 1550 started
# Episode 1600 started
# Reward checking: Episode: 1600, Total discounted reward: 1.6614997483251688
# Episode 1650 started
# Episode 1700 started
# Reward checking: Episode: 1700, Total discounted reward: 2.143422261977337
# Episode 1750 started
# Episode 1800 started
# Reward checking: Episode: 1800, Total discounted reward: 1.6485004060032418
# Episode 1850 started
# Episode 1900 started
# Reward checking: Episode: 1900, Total discounted reward: 2.5152129661824865
# Episode 1950 started
# Episode 2000 started
# Reward checking: Episode: 2000, Total discounted reward: 1.7950127210332631
# Episode 2050 started
# Episode 2100 started
# Reward checking: Episode: 2100, Total discounted reward: 1.7669771507627223
# Episode 2150 started
# Episode 2200 started
# Reward checking: Episode: 2200, Total discounted reward: 1.8333792329251195
# Episode 2250 started
# Episode 2300 started
# Reward checking: Episode: 2300, Total discounted reward: 1.9871221711138718
# Episode 2350 started
# Episode 2400 started
# Reward checking: Episode: 2400, Total discounted reward: 1.764600002946064
# Episode 2450 started
# Episode 2500 started
# Reward checking: Episode: 2500, Total discounted reward: 2.023404493709405
# Episode 2550 started
# Episode 2600 started
# Reward checking: Episode: 2600, Total discounted reward: 1.2775469214060682
# Episode 2650 started
# Episode 2700 started
# Reward checking: Episode: 2700, Total discounted reward: 0.0
# Episode 2750 started
# Episode 2800 started
# Reward checking: Episode: 2800, Total discounted reward: 0.987692923208082
# Episode 2850 started
# Episode 2900 started
# Reward checking: Episode: 2900, Total discounted reward: 2.025703254018834
# Episode 2950 started
# Episode 3000 started
# Reward checking: Episode: 3000, Total discounted reward: 1.8814088807570597
# Episode 3050 started
# Episode 3100 started
# Reward checking: Episode: 3100, Total discounted reward: 2.1203310390343746
# Episode 3150 started
# Episode 3200 started
# Reward checking: Episode: 3200, Total discounted reward: 2.110462435756177
# Episode 3250 started
# Episode 3300 started
# Reward checking: Episode: 3300, Total discounted reward: 2.1732018723169633
# Episode 3350 started
# Episode 3400 started
# Reward checking: Episode: 3400, Total discounted reward: 1.9076380225384515
# Episode 3450 started
# Episode 3500 started
# Reward checking: Episode: 3500, Total discounted reward: 2.062473135420861
# Episode 3550 started
# Episode 3600 started
# Reward checking: Episode: 3600, Total discounted reward: 1.9739355249812867
# Episode 3650 started
# Episode 3700 started
# Reward checking: Episode: 3700, Total discounted reward: 1.9918702884161683
# Episode 3750 started
# Episode 3800 started
# Reward checking: Episode: 3800, Total discounted reward: 2.272372181668957
# Episode 3850 started
# Episode 3900 started
# Reward checking: Episode: 3900, Total discounted reward: 2.116042938518041
# Episode 3950 started
# Episode 4000 started
# Reward checking: Episode: 4000, Total discounted reward: 2.101208719822813
# Episode 4050 started
# Episode 4100 started
# Reward checking: Episode: 4100, Total discounted reward: 2.0386925399625886
# Episode 4150 started
# Episode 4200 started
# Reward checking: Episode: 4200, Total discounted reward: 2.266046775596028
# Episode 4250 started
# Episode 4300 started
# Reward checking: Episode: 4300, Total discounted reward: 0.0
# Episode 4350 started
# Episode 4400 started
# Reward checking: Episode: 4400, Total discounted reward: 1.8115339850887964
# Episode 4450 started
# Episode 4500 started
# Reward checking: Episode: 4500, Total discounted reward: 0.6757290490602831
# Episode 4550 started
# Episode 4600 started
# Reward checking: Episode: 4600, Total discounted reward: 2.1311252258033475
# Episode 4650 started
# Episode 4700 started
# Reward checking: Episode: 4700, Total discounted reward: 2.171592202704929
# Episode 4750 started
# Episode 4800 started
# Reward checking: Episode: 4800, Total discounted reward: 1.8237927019903755
# Episode 4850 started
# Episode 4900 started
# Reward checking: Episode: 4900, Total discounted reward: 2.372949140106348
# Episode 4950 started
# Episode 5000 started
# Reward checking: Episode: 5000, Total discounted reward: 1.9787977720664331
# Episode 5050 started
# Episode 5100 started
# Reward checking: Episode: 5100, Total discounted reward: 2.628396814142528
# Episode 5150 started
# Episode 5200 started
# Reward checking: Episode: 5200, Total discounted reward: 1.9451252534340335
# Episode 5250 started
# Episode 5300 started
# Reward checking: Episode: 5300, Total discounted reward: 1.9909695536568945
# Episode 5350 started
# Episode 5400 started
# Reward checking: Episode: 5400, Total discounted reward: 1.9280685893203213
# Episode 5450 started
# Episode 5500 started
# Reward checking: Episode: 5500, Total discounted reward: 1.804237992986308
# Episode 5550 started
# Episode 5600 started
# Reward checking: Episode: 5600, Total discounted reward: 1.7994305899999068
# Episode 5650 started
# Episode 5700 started
# Reward checking: Episode: 5700, Total discounted reward: 2.4771334581707847
# Episode 5750 started
# Episode 5800 started
# Reward checking: Episode: 5800, Total discounted reward: 2.066351596965871
# Episode 5850 started
# Episode 5900 started
# Reward checking: Episode: 5900, Total discounted reward: 2.0863207894996854
# Episode 5950 started
# Episode 6000 started
# Reward checking: Episode: 6000, Total discounted reward: 2.298226729549616
# Episode 6050 started
# Episode 6100 started
# Reward checking: Episode: 6100, Total discounted reward: 0.0
# Episode 6150 started
# Episode 6200 started
# Reward checking: Episode: 6200, Total discounted reward: 1.5245587754323964
# Episode 6250 started
# Episode 6300 started
# Reward checking: Episode: 6300, Total discounted reward: 2.302716174162782
# Episode 6350 started
# Episode 6400 started
# Reward checking: Episode: 6400, Total discounted reward: 2.119179365775252
# Episode 6450 started
# Episode 6500 started
# Reward checking: Episode: 6500, Total discounted reward: 2.5374094626326613
# Episode 6550 started
# Episode 6600 started
# Reward checking: Episode: 6600, Total discounted reward: 2.0147029034297415
# Episode 6650 started
# Episode 6700 started
# Reward checking: Episode: 6700, Total discounted reward: 1.927593085625323
# Episode 6750 started
# Episode 6800 started
# Reward checking: Episode: 6800, Total discounted reward: 1.8070928743677992
# Episode 6850 started
# Episode 6900 started
# Reward checking: Episode: 6900, Total discounted reward: 1.9491327901861994
# Episode 6950 started
# Episode 7000 started
# Reward checking: Episode: 7000, Total discounted reward: 1.6607027551851195
# Episode 7050 started
# Episode 7100 started
# Reward checking: Episode: 7100, Total discounted reward: 1.8712675534702403
# Episode 7150 started
# Episode 7200 started
# Reward checking: Episode: 7200, Total discounted reward: 2.278742584326157
# Episode 7250 started
# Episode 7300 started
# Reward checking: Episode: 7300, Total discounted reward: 2.6088062797127782
# Episode 7350 started
# Episode 7400 started
# Reward checking: Episode: 7400, Total discounted reward: 2.115665767104385
# Episode 7450 started
# Episode 7500 started
# Reward checking: Episode: 7500, Total discounted reward: 2.227436164156625
# Episode 7550 started
# Episode 7600 started
# Reward checking: Episode: 7600, Total discounted reward: 2.073172496411738
# Episode 7650 started
# Episode 7700 started
# Reward checking: Episode: 7700, Total discounted reward: 2.061708660247327
# Episode 7750 started
# Episode 7800 started
# Reward checking: Episode: 7800, Total discounted reward: 3.506219559193508
# Episode 7850 started
# Episode 7900 started
# Reward checking: Episode: 7900, Total discounted reward: 1.8188916935641493
# Episode 7950 started
# Episode 8000 started
# Reward checking: Episode: 8000, Total discounted reward: 1.856352340260331
# Episode 8050 started
# Episode 8100 started
# Reward checking: Episode: 8100, Total discounted reward: 2.1484146010160354
# Episode 8150 started
# Episode 8200 started
# Reward checking: Episode: 8200, Total discounted reward: 2.2507086285407603
# Episode 8250 started
# Episode 8300 started
# Reward checking: Episode: 8300, Total discounted reward: 2.330634278393454
# Episode 8350 started
# Episode 8400 started
# Reward checking: Episode: 8400, Total discounted reward: 1.796951211719089
# Episode 8450 started
# Episode 8500 started
# Reward checking: Episode: 8500, Total discounted reward: 2.2501396915386445
# Episode 8550 started
# Episode 8600 started
# Reward checking: Episode: 8600, Total discounted reward: 1.8647591237411023
# Episode 8650 started
# Episode 8700 started
# Reward checking: Episode: 8700, Total discounted reward: 2.2899428478043067
# Episode 8750 started
# Episode 8800 started
# Reward checking: Episode: 8800, Total discounted reward: 2.2562999456174437
# Episode 8850 started
# Episode 8900 started
# Reward checking: Episode: 8900, Total discounted reward: 2.261708680404385
# Episode 8950 started
# Episode 9000 started
# Reward checking: Episode: 9000, Total discounted reward: 2.4019517643464945
# Episode 9050 started
# Episode 9100 started
# Reward checking: Episode: 9100, Total discounted reward: 2.1436701066823485
# Episode 9150 started
# Episode 9200 started
# Reward checking: Episode: 9200, Total discounted reward: 2.0910434717059747
# Episode 9250 started
# Episode 9300 started
# Reward checking: Episode: 9300, Total discounted reward: 1.9454471663917519
# Episode 9350 started
# Episode 9400 started
# Reward checking: Episode: 9400, Total discounted reward: 2.00817795691584
# Episode 9450 started
# Episode 9500 started
# Reward checking: Episode: 9500, Total discounted reward: 2.2496972778262756
# Episode 9550 started
# Episode 9600 started
# Reward checking: Episode: 9600, Total discounted reward: 2.4966547873390863
# Episode 9650 started
# Episode 9700 started
# Reward checking: Episode: 9700, Total discounted reward: 1.95251884465591
# Episode 9750 started
# Episode 9800 started
# Reward checking: Episode: 9800, Total discounted reward: 1.8199303967308782
# Episode 9850 started
# Episode 9900 started
# Reward checking: Episode: 9900, Total discounted reward: 2.039975576372659
# Episode 9950 started
# Episode 10000 started
# Reward checking: Episode: 10000, Total discounted reward: 2.226154590260039

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
