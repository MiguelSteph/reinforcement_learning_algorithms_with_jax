# %%
# !pip install gymnasium
# !pip install swig
# !pip install ale-py
# !pip install "gymnasium[atari]"
# !pip install "autorom[accept-rom-license]"
# !pip install -q ml-collections
# !pip install tensorboardX
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (2.4.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.4)
# Collecting swig
#   Downloading swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Downloading swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 6.7 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.4.1
# Requirement already satisfied: ale-py in /usr/local/lib/python3.12/dist-packages (0.11.2)
# Requirement already satisfied: numpy>1.20 in /usr/local/lib/python3.12/dist-packages (from ale-py) (2.4.6)
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (2.4.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (0.11.2)
# Collecting autorom[accept-rom-license]
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from autorom[accept-rom-license]) (8.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from autorom[accept-rom-license]) (2.32.4)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 18.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (2026.2.25)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=autorom_accept_rom_license-0.6.1-py3-none-any.whl size=446710 sha256=9581feba116c60391912570105b6e9cc157b187c607301b7add6e4a4b890264a
#   Stored in directory: /root/.cache/pip/wheels/99/f1/ff/c6966c034a8259164bdc9deb4d1ea839f119474638100e6645
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 autorom-0.6.1
# Collecting tensorboardX
#   Downloading tensorboardx-2.6.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (2.4.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (26.2)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (5.29.5)
# Downloading tensorboardx-2.6.5-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.5

# %%
import os
import urllib.request
from urllib.error import HTTPError

# %%
# !rm -f configs.py ppo_types.py model.py trainer.py agent.py envs_wrapper.py

# %%
base_url = "https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/ppo/"

def download_file_from_github(file_path: str, file_name: str):
    if not os.path.isfile(file_name):
        file_url = base_url + file_path
        print(f"Downloading {file_url}...")
        try:
            urllib.request.urlretrieve(file_url, file_name)
        except HTTPError as e:
            print("Something went wrong. Please try to download the file directly from the GitHub repository:\n", e)


file_paths = [
    'ppo/configs.py',
    'ppo/ppo_types.py',
    'ppo/model.py',
    'ppo/trainer.py',
    'ppo/agent.py',
    'ppo/envs_wrapper.py',
]
file_names = [
    'configs.py',
    'ppo_types.py',
    'model.py',
    'trainer.py',
    'agent.py',
    'envs_wrapper.py',
]

for file_path, file_name in zip(file_paths, file_names): 
    download_file_from_github(file_path, file_name)
# Out:
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/ppo/ppo/configs.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/ppo/ppo/ppo_types.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/ppo/ppo/model.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/ppo/ppo/trainer.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/ppo/ppo/agent.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/ppo/ppo/envs_wrapper.py...

# %%
from ppo_types import NetworkConfig, TrainerConfig
from agent import Agent
from trainer import AgentTrainer
import jax

# %%
network_config = NetworkConfig()
trainer_config = TrainerConfig()

initial_rng_key = jax.random.key(18)
agent_rng_key, trainer_rng_key = jax.random.split(initial_rng_key)

agent = Agent(network_config)
state = agent.init(agent_rng_key, trainer_config.obs_shape, trainer_config.learning_rate)

trainer = AgentTrainer(agent, trainer_config, trainer_rng_key)
state = trainer.run_train_loop(state)
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# /usr/lib/python3.12/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Rollout 50 started
# Evaluation: Rollout: 50, Avg rewards sum: 1.5666667222976685
# Rollout 100 started
# Evaluation: Rollout: 100, Avg rewards sum: 1.5666667222976685
# Rollout 150 started
# Evaluation: Rollout: 150, Avg rewards sum: 2.4000000953674316
# Rollout 200 started
# Evaluation: Rollout: 200, Avg rewards sum: 2.5333333015441895
# Rollout 250 started
# Evaluation: Rollout: 250, Avg rewards sum: 2.7333333492279053
# Rollout 300 started
# Evaluation: Rollout: 300, Avg rewards sum: 3.0999999046325684
# Rollout 350 started
# Evaluation: Rollout: 350, Avg rewards sum: 3.566666603088379
# Rollout 400 started
# Evaluation: Rollout: 400, Avg rewards sum: 3.2666666507720947
# Rollout 450 started
# Evaluation: Rollout: 450, Avg rewards sum: 3.4666666984558105
# Rollout 500 started
# Evaluation: Rollout: 500, Avg rewards sum: 3.4000000953674316
# Rollout 550 started
# Evaluation: Rollout: 550, Avg rewards sum: 3.5
# Rollout 600 started
# Evaluation: Rollout: 600, Avg rewards sum: 4.300000190734863
# Rollout 650 started
# Evaluation: Rollout: 650, Avg rewards sum: 4.066666603088379
# Rollout 700 started
# Evaluation: Rollout: 700, Avg rewards sum: 3.866666555404663
# Rollout 750 started
# Evaluation: Rollout: 750, Avg rewards sum: 3.9000000953674316
# Rollout 800 started
# Evaluation: Rollout: 800, Avg rewards sum: 4.233333110809326
# Rollout 850 started
# Evaluation: Rollout: 850, Avg rewards sum: 3.9666666984558105
# Rollout 900 started
# Evaluation: Rollout: 900, Avg rewards sum: 3.366666555404663
# Rollout 950 started
# Evaluation: Rollout: 950, Avg rewards sum: 3.933333396911621
# Rollout 1000 started
# Evaluation: Rollout: 1000, Avg rewards sum: 5.233333110809326
# Rollout 1050 started
# Evaluation: Rollout: 1050, Avg rewards sum: 5.0333333015441895
# Rollout 1100 started
# Evaluation: Rollout: 1100, Avg rewards sum: 5.866666793823242
# Rollout 1150 started
# Evaluation: Rollout: 1150, Avg rewards sum: 4.900000095367432
# Rollout 1200 started
# Evaluation: Rollout: 1200, Avg rewards sum: 4.433333396911621
# Rollout 1250 started
# Evaluation: Rollout: 1250, Avg rewards sum: 5.099999904632568
# Rollout 1300 started
# Evaluation: Rollout: 1300, Avg rewards sum: 7.0
# Rollout 1350 started
# Evaluation: Rollout: 1350, Avg rewards sum: 7.0333333015441895
# Rollout 1400 started
# Evaluation: Rollout: 1400, Avg rewards sum: 6.733333110809326
# Rollout 1450 started
# Evaluation: Rollout: 1450, Avg rewards sum: 6.066666603088379
# Rollout 1500 started
# Evaluation: Rollout: 1500, Avg rewards sum: 5.900000095367432
# Rollout 1550 started
# Evaluation: Rollout: 1550, Avg rewards sum: 6.900000095367432
# Rollout 1600 started
# Evaluation: Rollout: 1600, Avg rewards sum: 5.733333110809326
# Rollout 1650 started
# Evaluation: Rollout: 1650, Avg rewards sum: 7.0
# Rollout 1700 started
# Evaluation: Rollout: 1700, Avg rewards sum: 7.766666889190674
# Rollout 1750 started
# Evaluation: Rollout: 1750, Avg rewards sum: 7.5
# Rollout 1800 started
# Evaluation: Rollout: 1800, Avg rewards sum: 8.766666412353516
# Rollout 1850 started
# Evaluation: Rollout: 1850, Avg rewards sum: 9.133333206176758
# Rollout 1900 started
# Evaluation: Rollout: 1900, Avg rewards sum: 7.900000095367432
# Rollout 1950 started
# Evaluation: Rollout: 1950, Avg rewards sum: 11.133333206176758
# Rollout 2000 started
# Evaluation: Rollout: 2000, Avg rewards sum: 10.933333396911621
# Rollout 2050 started
# Evaluation: Rollout: 2050, Avg rewards sum: 6.366666793823242
# Rollout 2100 started
# Evaluation: Rollout: 2100, Avg rewards sum: 10.133333206176758
# Rollout 2150 started
# Evaluation: Rollout: 2150, Avg rewards sum: 11.5
# Rollout 2200 started
# Evaluation: Rollout: 2200, Avg rewards sum: 9.733333587646484
# Rollout 2250 started
# Evaluation: Rollout: 2250, Avg rewards sum: 12.866666793823242
# Rollout 2300 started
# Evaluation: Rollout: 2300, Avg rewards sum: 10.699999809265137
# Rollout 2350 started
# Evaluation: Rollout: 2350, Avg rewards sum: 15.633333206176758
# Rollout 2400 started
# Evaluation: Rollout: 2400, Avg rewards sum: 10.666666984558105
# Rollout 2450 started
# Evaluation: Rollout: 2450, Avg rewards sum: 12.933333396911621
# Rollout 2500 started
# Evaluation: Rollout: 2500, Avg rewards sum: 12.966666221618652
# Rollout 2550 started
# Evaluation: Rollout: 2550, Avg rewards sum: 12.666666984558105
# Rollout 2600 started
# Evaluation: Rollout: 2600, Avg rewards sum: 12.966666221618652
# Rollout 2650 started
# Evaluation: Rollout: 2650, Avg rewards sum: 16.46666717529297
# Rollout 2700 started
# Evaluation: Rollout: 2700, Avg rewards sum: 17.700000762939453
# Rollout 2750 started
# Evaluation: Rollout: 2750, Avg rewards sum: 12.133333206176758
# Rollout 2800 started
# Evaluation: Rollout: 2800, Avg rewards sum: 12.300000190734863
# Rollout 2850 started
# Evaluation: Rollout: 2850, Avg rewards sum: 12.866666793823242
# Rollout 2900 started
# Evaluation: Rollout: 2900, Avg rewards sum: 13.399999618530273
# Rollout 2950 started
# Evaluation: Rollout: 2950, Avg rewards sum: 11.600000381469727
# Rollout 3000 started
# Evaluation: Rollout: 3000, Avg rewards sum: 15.166666984558105
# Rollout 3050 started
# Evaluation: Rollout: 3050, Avg rewards sum: 16.799999237060547
# Rollout 3100 started
# Evaluation: Rollout: 3100, Avg rewards sum: 14.366666793823242
# Rollout 3150 started
# Evaluation: Rollout: 3150, Avg rewards sum: 15.833333015441895
# Rollout 3200 started
# Evaluation: Rollout: 3200, Avg rewards sum: 18.366666793823242
# Rollout 3250 started
# Evaluation: Rollout: 3250, Avg rewards sum: 17.200000762939453
# Rollout 3300 started
# Evaluation: Rollout: 3300, Avg rewards sum: 13.466666221618652
# Rollout 3350 started
# Evaluation: Rollout: 3350, Avg rewards sum: 18.733333587646484
# Rollout 3400 started
# Evaluation: Rollout: 3400, Avg rewards sum: 18.100000381469727
# Rollout 3450 started
# Evaluation: Rollout: 3450, Avg rewards sum: 11.466666221618652
# Rollout 3500 started
# Evaluation: Rollout: 3500, Avg rewards sum: 17.200000762939453
# Rollout 3550 started
# Evaluation: Rollout: 3550, Avg rewards sum: 14.733333587646484
# Rollout 3600 started
# Evaluation: Rollout: 3600, Avg rewards sum: 12.199999809265137
# Rollout 3650 started
# Evaluation: Rollout: 3650, Avg rewards sum: 19.866666793823242
# Rollout 3700 started
# Evaluation: Rollout: 3700, Avg rewards sum: 21.866666793823242
# Rollout 3750 started
# Evaluation: Rollout: 3750, Avg rewards sum: 22.566667556762695
# Rollout 3800 started
# Evaluation: Rollout: 3800, Avg rewards sum: 22.53333282470703
# Rollout 3850 started
# Evaluation: Rollout: 3850, Avg rewards sum: 22.266666412353516
# Rollout 3900 started
# Evaluation: Rollout: 3900, Avg rewards sum: 21.96666717529297
# Rollout 3950 started
# Evaluation: Rollout: 3950, Avg rewards sum: 20.633333206176758
# Rollout 4000 started
# Evaluation: Rollout: 4000, Avg rewards sum: 19.133333206176758
# Rollout 4050 started
# Evaluation: Rollout: 4050, Avg rewards sum: 24.866666793823242
# Rollout 4100 started
# Evaluation: Rollout: 4100, Avg rewards sum: 23.200000762939453
# Rollout 4150 started
# Evaluation: Rollout: 4150, Avg rewards sum: 18.100000381469727
# Rollout 4200 started
# Evaluation: Rollout: 4200, Avg rewards sum: 23.866666793823242
# Rollout 4250 started
# Evaluation: Rollout: 4250, Avg rewards sum: 17.633333206176758
# Rollout 4300 started
# Evaluation: Rollout: 4300, Avg rewards sum: 24.600000381469727
# Rollout 4350 started
# Evaluation: Rollout: 4350, Avg rewards sum: 22.600000381469727
# Rollout 4400 started
# Evaluation: Rollout: 4400, Avg rewards sum: 22.866666793823242
# Rollout 4450 started
# Evaluation: Rollout: 4450, Avg rewards sum: 18.566667556762695
# Rollout 4500 started
# Evaluation: Rollout: 4500, Avg rewards sum: 18.066667556762695
# Rollout 4550 started
# Evaluation: Rollout: 4550, Avg rewards sum: 24.899999618530273
# Rollout 4600 started
# Evaluation: Rollout: 4600, Avg rewards sum: 19.100000381469727
# Rollout 4650 started
# Evaluation: Rollout: 4650, Avg rewards sum: 21.933332443237305
# Rollout 4700 started
# Evaluation: Rollout: 4700, Avg rewards sum: 17.066667556762695
# Rollout 4750 started
# Evaluation: Rollout: 4750, Avg rewards sum: 18.733333587646484
# Rollout 4800 started
# Evaluation: Rollout: 4800, Avg rewards sum: 21.233333587646484
# Rollout 4850 started
# Evaluation: Rollout: 4850, Avg rewards sum: 17.933332443237305
# Rollout 4900 started
# Evaluation: Rollout: 4900, Avg rewards sum: 14.5
# Rollout 4950 started
# Evaluation: Rollout: 4950, Avg rewards sum: 29.733333587646484
# Rollout 5000 started
# Evaluation: Rollout: 5000, Avg rewards sum: 26.96666717529297
# Rollout 5050 started
# Evaluation: Rollout: 5050, Avg rewards sum: 26.233333587646484
# Rollout 5100 started
# Evaluation: Rollout: 5100, Avg rewards sum: 18.433332443237305
# Rollout 5150 started
# Evaluation: Rollout: 5150, Avg rewards sum: 23.399999618530273
# Rollout 5200 started
# Evaluation: Rollout: 5200, Avg rewards sum: 19.03333282470703
# Rollout 5250 started
# Evaluation: Rollout: 5250, Avg rewards sum: 25.366666793823242
# Rollout 5300 started
# Evaluation: Rollout: 5300, Avg rewards sum: 26.899999618530273
# Rollout 5350 started
# Evaluation: Rollout: 5350, Avg rewards sum: 21.46666717529297
# Rollout 5400 started
# Evaluation: Rollout: 5400, Avg rewards sum: 22.399999618530273
# Rollout 5450 started
# Evaluation: Rollout: 5450, Avg rewards sum: 20.433332443237305
# Rollout 5500 started
# Evaluation: Rollout: 5500, Avg rewards sum: 20.53333282470703
# Rollout 5550 started
# Evaluation: Rollout: 5550, Avg rewards sum: 28.46666717529297
# Rollout 5600 started
# Evaluation: Rollout: 5600, Avg rewards sum: 24.133333206176758
# Rollout 5650 started
# Evaluation: Rollout: 5650, Avg rewards sum: 23.46666717529297
# Rollout 5700 started
# Evaluation: Rollout: 5700, Avg rewards sum: 22.66666603088379
# Rollout 5750 started
# Evaluation: Rollout: 5750, Avg rewards sum: 24.700000762939453
# Rollout 5800 started
# Evaluation: Rollout: 5800, Avg rewards sum: 25.5
# Rollout 5850 started
# Evaluation: Rollout: 5850, Avg rewards sum: 29.633333206176758
# Rollout 5900 started
# Evaluation: Rollout: 5900, Avg rewards sum: 25.733333587646484
# Rollout 5950 started
# Evaluation: Rollout: 5950, Avg rewards sum: 29.600000381469727
# Rollout 6000 started
# Evaluation: Rollout: 6000, Avg rewards sum: 28.0
# Rollout 6050 started
# Evaluation: Rollout: 6050, Avg rewards sum: 20.83333396911621
# Rollout 6100 started
# Evaluation: Rollout: 6100, Avg rewards sum: 32.16666793823242
# Rollout 6150 started
# Evaluation: Rollout: 6150, Avg rewards sum: 23.899999618530273
# Rollout 6200 started
# Evaluation: Rollout: 6200, Avg rewards sum: 21.866666793823242
# Rollout 6250 started
# Evaluation: Rollout: 6250, Avg rewards sum: 23.100000381469727
# Rollout 6300 started
# Evaluation: Rollout: 6300, Avg rewards sum: 25.566667556762695
# Rollout 6350 started
# Evaluation: Rollout: 6350, Avg rewards sum: 23.83333396911621
# Rollout 6400 started
# Evaluation: Rollout: 6400, Avg rewards sum: 21.16666603088379
# Rollout 6450 started
# Evaluation: Rollout: 6450, Avg rewards sum: 25.133333206176758
# Rollout 6500 started
# Evaluation: Rollout: 6500, Avg rewards sum: 26.03333282470703
# Rollout 6550 started
# Evaluation: Rollout: 6550, Avg rewards sum: 20.433332443237305
# Rollout 6600 started
# Evaluation: Rollout: 6600, Avg rewards sum: 22.96666717529297
# Rollout 6650 started
# Evaluation: Rollout: 6650, Avg rewards sum: 18.33333396911621
# Rollout 6700 started
# Evaluation: Rollout: 6700, Avg rewards sum: 20.66666603088379
# Rollout 6750 started
# Evaluation: Rollout: 6750, Avg rewards sum: 23.633333206176758
# Rollout 6800 started
# Evaluation: Rollout: 6800, Avg rewards sum: 21.16666603088379
# Rollout 6850 started
# Evaluation: Rollout: 6850, Avg rewards sum: 19.16666603088379
# Rollout 6900 started
# Evaluation: Rollout: 6900, Avg rewards sum: 17.83333396911621
# Rollout 6950 started
# Evaluation: Rollout: 6950, Avg rewards sum: 21.133333206176758
# Rollout 7000 started
# Evaluation: Rollout: 7000, Avg rewards sum: 19.799999237060547
# Rollout 7050 started
# Evaluation: Rollout: 7050, Avg rewards sum: 27.766666412353516
# Rollout 7100 started
# Evaluation: Rollout: 7100, Avg rewards sum: 19.83333396911621
# Rollout 7150 started
# Evaluation: Rollout: 7150, Avg rewards sum: 24.100000381469727
# Rollout 7200 started
# Evaluation: Rollout: 7200, Avg rewards sum: 24.433332443237305
# Rollout 7250 started
# Evaluation: Rollout: 7250, Avg rewards sum: 25.100000381469727
# Rollout 7300 started
# Evaluation: Rollout: 7300, Avg rewards sum: 22.46666717529297
# Rollout 7350 started
# Evaluation: Rollout: 7350, Avg rewards sum: 23.96666717529297
# Rollout 7400 started
# Evaluation: Rollout: 7400, Avg rewards sum: 24.0
# Rollout 7450 started
# Evaluation: Rollout: 7450, Avg rewards sum: 24.366666793823242
# Rollout 7500 started
# Evaluation: Rollout: 7500, Avg rewards sum: 19.566667556762695
# Rollout 7550 started
# Evaluation: Rollout: 7550, Avg rewards sum: 21.799999237060547
# Rollout 7600 started
# Evaluation: Rollout: 7600, Avg rewards sum: 19.366666793823242
# Rollout 7650 started
# Evaluation: Rollout: 7650, Avg rewards sum: 18.53333282470703
# Rollout 7700 started
# Evaluation: Rollout: 7700, Avg rewards sum: 19.433332443237305
# Rollout 7750 started
# Evaluation: Rollout: 7750, Avg rewards sum: 19.600000381469727
# Rollout 7800 started
# Evaluation: Rollout: 7800, Avg rewards sum: 18.83333396911621
# Rollout 7850 started
# Evaluation: Rollout: 7850, Avg rewards sum: 16.66666603088379
# Rollout 7900 started
# Evaluation: Rollout: 7900, Avg rewards sum: 17.266666412353516
# Rollout 7950 started
# Evaluation: Rollout: 7950, Avg rewards sum: 22.933332443237305
# Rollout 8000 started
# Evaluation: Rollout: 8000, Avg rewards sum: 21.766666412353516
# Rollout 8050 started
# Evaluation: Rollout: 8050, Avg rewards sum: 18.03333282470703
# Rollout 8100 started
# Evaluation: Rollout: 8100, Avg rewards sum: 17.96666717529297
# Rollout 8150 started
# Evaluation: Rollout: 8150, Avg rewards sum: 19.566667556762695
# Rollout 8200 started
# Evaluation: Rollout: 8200, Avg rewards sum: 20.200000762939453
# Rollout 8250 started
# Evaluation: Rollout: 8250, Avg rewards sum: 16.766666412353516
# Rollout 8300 started
# Evaluation: Rollout: 8300, Avg rewards sum: 18.46666717529297
# Rollout 8350 started
# Evaluation: Rollout: 8350, Avg rewards sum: 17.566667556762695
# Rollout 8400 started
# Evaluation: Rollout: 8400, Avg rewards sum: 16.899999618530273
# Rollout 8450 started
# Evaluation: Rollout: 8450, Avg rewards sum: 16.566667556762695
# Rollout 8500 started
# Evaluation: Rollout: 8500, Avg rewards sum: 21.53333282470703
# Rollout 8550 started
# Evaluation: Rollout: 8550, Avg rewards sum: 18.100000381469727
# Rollout 8600 started
# Evaluation: Rollout: 8600, Avg rewards sum: 19.100000381469727
# Rollout 8650 started
# Evaluation: Rollout: 8650, Avg rewards sum: 20.433332443237305
# Rollout 8700 started
# Evaluation: Rollout: 8700, Avg rewards sum: 22.233333587646484
# Rollout 8750 started
# Evaluation: Rollout: 8750, Avg rewards sum: 20.233333587646484
# Rollout 8800 started
# Evaluation: Rollout: 8800, Avg rewards sum: 19.16666603088379
# Rollout 8850 started
# Evaluation: Rollout: 8850, Avg rewards sum: 17.866666793823242
# Rollout 8900 started
# Evaluation: Rollout: 8900, Avg rewards sum: 17.46666717529297
# Rollout 8950 started
# Evaluation: Rollout: 8950, Avg rewards sum: 19.733333587646484
# Rollout 9000 started
# Evaluation: Rollout: 9000, Avg rewards sum: 16.96666717529297
# Rollout 9050 started
# Evaluation: Rollout: 9050, Avg rewards sum: 16.700000762939453
# Rollout 9100 started
# Evaluation: Rollout: 9100, Avg rewards sum: 17.66666603088379
# Rollout 9150 started
# Evaluation: Rollout: 9150, Avg rewards sum: 20.266666412353516
# Rollout 9200 started
# Evaluation: Rollout: 9200, Avg rewards sum: 20.03333282470703
# Rollout 9250 started
# Evaluation: Rollout: 9250, Avg rewards sum: 17.899999618530273
# Rollout 9300 started
# Evaluation: Rollout: 9300, Avg rewards sum: 22.700000762939453
# Rollout 9350 started
# Evaluation: Rollout: 9350, Avg rewards sum: 16.933332443237305
# Rollout 9400 started
# Evaluation: Rollout: 9400, Avg rewards sum: 20.46666717529297
# Rollout 9450 started
# Evaluation: Rollout: 9450, Avg rewards sum: 23.799999237060547
# Rollout 9500 started
# Evaluation: Rollout: 9500, Avg rewards sum: 13.399999618530273
# Rollout 9550 started
# Evaluation: Rollout: 9550, Avg rewards sum: 19.83333396911621
# Rollout 9600 started
# Evaluation: Rollout: 9600, Avg rewards sum: 18.0
# Rollout 9650 started
# Evaluation: Rollout: 9650, Avg rewards sum: 27.600000381469727
# Rollout 9700 started
# Evaluation: Rollout: 9700, Avg rewards sum: 18.600000381469727
# Rollout 9750 started
# Evaluation: Rollout: 9750, Avg rewards sum: 17.433332443237305
# Rollout 9800 started
# Evaluation: Rollout: 9800, Avg rewards sum: 19.600000381469727
# Rollout 9850 started
# Evaluation: Rollout: 9850, Avg rewards sum: 24.366666793823242
# Rollout 9900 started
# Evaluation: Rollout: 9900, Avg rewards sum: 23.66666603088379
# Rollout 9950 started
# Evaluation: Rollout: 9950, Avg rewards sum: 12.333333015441895
# Rollout 10000 started
# /usr/lib/python3.12/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Evaluation: Rollout: 10000, Avg rewards sum: 18.866666793823242
