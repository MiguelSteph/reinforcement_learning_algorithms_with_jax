# %%
# !pip install gymnasium
# !pip install swig
# !pip install ale-py
# !pip install "gymnasium[atari]"
# !pip install "autorom[accept-rom-license]"
# !pip install -q ml-collections
# !pip install tensorboardX
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (2.4.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.4)
# Collecting swig
#   Downloading swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Downloading swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 34.6 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.4.1
# Requirement already satisfied: ale-py in /usr/local/lib/python3.12/dist-packages (0.11.2)
# Requirement already satisfied: numpy>1.20 in /usr/local/lib/python3.12/dist-packages (from ale-py) (2.4.6)
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (2.4.6)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: ale_py>=0.9 in /usr/local/lib/python3.12/dist-packages (from gymnasium[atari]) (0.11.2)
# Collecting autorom[accept-rom-license]
#   Downloading AutoROM-0.6.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from autorom[accept-rom-license]) (8.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from autorom[accept-rom-license]) (2.32.4)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 7.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->autorom[accept-rom-license]) (2026.2.25)
# Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=autorom_accept_rom_license-0.6.1-py3-none-any.whl size=446710 sha256=75cf18a724d27edbd876a1ba850c546c06d2a71e77d180b51e6b00c224a320a0
#   Stored in directory: /root/.cache/pip/wheels/99/f1/ff/c6966c034a8259164bdc9deb4d1ea839f119474638100e6645
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 autorom-0.6.1
# Collecting tensorboardX
#   Downloading tensorboardx-2.6.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (2.4.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (26.2)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorboardX) (5.29.5)
# Downloading tensorboardx-2.6.5-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: tensorboardX
# Successfully installed tensorboardX-2.6.5

# %%
import os
import urllib.request
from urllib.error import HTTPError

# %%
# !rm -f configs.py ppo_types.py model.py trainer.py agent.py envs_wrapper.py

# %%
base_url = "https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/ppo/"

def download_file_from_github(file_path: str, file_name: str):
    if not os.path.isfile(file_name):
        file_url = base_url + file_path
        print(f"Downloading {file_url}...")
        try:
            urllib.request.urlretrieve(file_url, file_name)
        except HTTPError as e:
            print("Something went wrong. Please try to download the file directly from the GitHub repository:\n", e)


file_paths = [
    'ppo/configs.py',
    'ppo/ppo_types.py',
    'ppo/model.py',
    'ppo/trainer.py',
    'ppo/agent.py',
    'ppo/envs_wrapper.py',
]
file_names = [
    'configs.py',
    'ppo_types.py',
    'model.py',
    'trainer.py',
    'agent.py',
    'envs_wrapper.py',
]

for file_path, file_name in zip(file_paths, file_names): 
    download_file_from_github(file_path, file_name)
# Out:
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/ppo/ppo/configs.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/ppo/ppo/ppo_types.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/ppo/ppo/model.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/ppo/ppo/trainer.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/ppo/ppo/agent.py...
# Downloading https://raw.githubusercontent.com/MiguelSteph/reinforcement_learning_algorithms_with_jax/ppo/ppo/envs_wrapper.py...

# %%
from ppo_types import NetworkConfig, TrainerConfig
from agent import Agent
from trainer import AgentTrainer
import jax

# %%
network_config = NetworkConfig()
trainer_config = TrainerConfig()

initial_rng_key = jax.random.key(18)
agent_rng_key, trainer_rng_key = jax.random.split(initial_rng_key)

agent = Agent(network_config)
state = agent.init(agent_rng_key, trainer_config.obs_shape, trainer_config.learning_rate)

trainer = AgentTrainer(agent, trainer_config, trainer_rng_key)
state = trainer.run_train_loop(state)
# Out:
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# /usr/lib/python3.12/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/2000 [00:00<?, ?it/s]
# Evaluation: Rollout: 20, Avg rewards sum: 0.46666666865348816
# Evaluation: Rollout: 40, Avg rewards sum: 0.5666666626930237
# Rollout 50 started
# Evaluation: Rollout: 60, Avg rewards sum: 0.699999988079071
# Evaluation: Rollout: 80, Avg rewards sum: 1.2000000476837158
# Rollout 100 started
# Evaluation: Rollout: 100, Avg rewards sum: 1.9333332777023315
# Evaluation: Rollout: 120, Avg rewards sum: 2.1666667461395264
# Evaluation: Rollout: 140, Avg rewards sum: 1.899999976158142
# Rollout 150 started
# Evaluation: Rollout: 160, Avg rewards sum: 3.0999999046325684
# Evaluation: Rollout: 180, Avg rewards sum: 2.8333332538604736
# Rollout 200 started
# Evaluation: Rollout: 200, Avg rewards sum: 2.4666666984558105
# Evaluation: Rollout: 220, Avg rewards sum: 2.9000000953674316
# Evaluation: Rollout: 240, Avg rewards sum: 2.2333333492279053
# Rollout 250 started
# Evaluation: Rollout: 260, Avg rewards sum: 3.0
# Evaluation: Rollout: 280, Avg rewards sum: 3.5
# Rollout 300 started
# Evaluation: Rollout: 300, Avg rewards sum: 2.5999999046325684
# Evaluation: Rollout: 320, Avg rewards sum: 2.3333332538604736
# Evaluation: Rollout: 340, Avg rewards sum: 2.9666666984558105
# Rollout 350 started
# Evaluation: Rollout: 360, Avg rewards sum: 2.9666666984558105
# Evaluation: Rollout: 380, Avg rewards sum: 2.866666555404663
# Rollout 400 started
# Evaluation: Rollout: 400, Avg rewards sum: 3.5333333015441895
# Evaluation: Rollout: 420, Avg rewards sum: 3.6666667461395264
# Evaluation: Rollout: 440, Avg rewards sum: 3.933333396911621
# Rollout 450 started
# Evaluation: Rollout: 460, Avg rewards sum: 3.1666667461395264
# Evaluation: Rollout: 480, Avg rewards sum: 3.9000000953674316
# Rollout 500 started
# Evaluation: Rollout: 500, Avg rewards sum: 3.200000047683716
# Evaluation: Rollout: 520, Avg rewards sum: 3.8333332538604736
# Evaluation: Rollout: 540, Avg rewards sum: 3.7333333492279053
# Rollout 550 started
# Evaluation: Rollout: 560, Avg rewards sum: 3.700000047683716
# Evaluation: Rollout: 580, Avg rewards sum: 4.233333110809326
# Rollout 600 started
# Evaluation: Rollout: 600, Avg rewards sum: 4.066666603088379
# Evaluation: Rollout: 620, Avg rewards sum: 3.9666666984558105
# Evaluation: Rollout: 640, Avg rewards sum: 3.700000047683716
# Rollout 650 started
# Evaluation: Rollout: 660, Avg rewards sum: 3.8333332538604736
# Evaluation: Rollout: 680, Avg rewards sum: 2.866666555404663
# Rollout 700 started
# Evaluation: Rollout: 700, Avg rewards sum: 4.166666507720947
# Evaluation: Rollout: 720, Avg rewards sum: 3.7666666507720947
# Evaluation: Rollout: 740, Avg rewards sum: 4.300000190734863
# Rollout 750 started
# Evaluation: Rollout: 760, Avg rewards sum: 4.166666507720947
# Evaluation: Rollout: 780, Avg rewards sum: 4.4666666984558105
# Rollout 800 started
# Evaluation: Rollout: 800, Avg rewards sum: 4.300000190734863
# Evaluation: Rollout: 820, Avg rewards sum: 5.199999809265137
# Evaluation: Rollout: 840, Avg rewards sum: 4.866666793823242
# Rollout 850 started
# Evaluation: Rollout: 860, Avg rewards sum: 5.166666507720947
# Evaluation: Rollout: 880, Avg rewards sum: 4.599999904632568
# Rollout 900 started
# Evaluation: Rollout: 900, Avg rewards sum: 4.800000190734863
# Evaluation: Rollout: 920, Avg rewards sum: 5.133333206176758
# Evaluation: Rollout: 940, Avg rewards sum: 5.099999904632568
# Rollout 950 started
# Evaluation: Rollout: 960, Avg rewards sum: 5.133333206176758
# Evaluation: Rollout: 980, Avg rewards sum: 5.333333492279053
# Rollout 1000 started
# Evaluation: Rollout: 1000, Avg rewards sum: 4.833333492279053
# Evaluation: Rollout: 1020, Avg rewards sum: 4.900000095367432
# Evaluation: Rollout: 1040, Avg rewards sum: 5.800000190734863
# Rollout 1050 started
# Evaluation: Rollout: 1060, Avg rewards sum: 4.833333492279053
# Evaluation: Rollout: 1080, Avg rewards sum: 4.133333206176758
# Rollout 1100 started
# Evaluation: Rollout: 1100, Avg rewards sum: 5.599999904632568
# Evaluation: Rollout: 1120, Avg rewards sum: 5.266666889190674
# Evaluation: Rollout: 1140, Avg rewards sum: 5.300000190734863
# Rollout 1150 started
# Evaluation: Rollout: 1160, Avg rewards sum: 6.133333206176758
# Evaluation: Rollout: 1180, Avg rewards sum: 5.699999809265137
# Rollout 1200 started
# Evaluation: Rollout: 1200, Avg rewards sum: 5.099999904632568
# Evaluation: Rollout: 1220, Avg rewards sum: 6.266666889190674
# Evaluation: Rollout: 1240, Avg rewards sum: 5.4666666984558105
# Rollout 1250 started
# Evaluation: Rollout: 1260, Avg rewards sum: 5.699999809265137
# Evaluation: Rollout: 1280, Avg rewards sum: 6.166666507720947
# Rollout 1300 started
# Evaluation: Rollout: 1300, Avg rewards sum: 6.4666666984558105
# Evaluation: Rollout: 1320, Avg rewards sum: 6.633333206176758
# Evaluation: Rollout: 1340, Avg rewards sum: 8.600000381469727
# Rollout 1350 started
# Evaluation: Rollout: 1360, Avg rewards sum: 7.566666603088379
# Evaluation: Rollout: 1380, Avg rewards sum: 6.099999904632568
# Rollout 1400 started
# Evaluation: Rollout: 1400, Avg rewards sum: 7.0333333015441895
# Evaluation: Rollout: 1420, Avg rewards sum: 6.400000095367432
# Evaluation: Rollout: 1440, Avg rewards sum: 6.733333110809326
# Rollout 1450 started
# Evaluation: Rollout: 1460, Avg rewards sum: 8.433333396911621
# Evaluation: Rollout: 1480, Avg rewards sum: 8.633333206176758
# Rollout 1500 started
# Evaluation: Rollout: 1500, Avg rewards sum: 7.066666603088379
# Evaluation: Rollout: 1520, Avg rewards sum: 8.633333206176758
# Evaluation: Rollout: 1540, Avg rewards sum: 7.833333492279053
# Rollout 1550 started
# Evaluation: Rollout: 1560, Avg rewards sum: 8.433333396911621
# Evaluation: Rollout: 1580, Avg rewards sum: 7.800000190734863
# Rollout 1600 started
# Evaluation: Rollout: 1600, Avg rewards sum: 7.766666889190674
# Evaluation: Rollout: 1620, Avg rewards sum: 9.333333015441895
# Evaluation: Rollout: 1640, Avg rewards sum: 6.433333396911621
# Rollout 1650 started
# Evaluation: Rollout: 1660, Avg rewards sum: 7.866666793823242
# Evaluation: Rollout: 1680, Avg rewards sum: 9.399999618530273
# Rollout 1700 started
# Evaluation: Rollout: 1700, Avg rewards sum: 7.433333396911621
# Evaluation: Rollout: 1720, Avg rewards sum: 12.533333778381348
# Evaluation: Rollout: 1740, Avg rewards sum: 11.100000381469727
# Rollout 1750 started
# Evaluation: Rollout: 1760, Avg rewards sum: 11.166666984558105
# Evaluation: Rollout: 1780, Avg rewards sum: 12.133333206176758
# Rollout 1800 started
# Evaluation: Rollout: 1800, Avg rewards sum: 12.199999809265137
# Evaluation: Rollout: 1820, Avg rewards sum: 15.833333015441895
# Evaluation: Rollout: 1840, Avg rewards sum: 9.866666793823242
# Rollout 1850 started
# Evaluation: Rollout: 1860, Avg rewards sum: 16.03333282470703
# Evaluation: Rollout: 1880, Avg rewards sum: 11.933333396911621
# Rollout 1900 started
# Evaluation: Rollout: 1900, Avg rewards sum: 12.766666412353516
# Evaluation: Rollout: 1920, Avg rewards sum: 11.466666221618652
# Evaluation: Rollout: 1940, Avg rewards sum: 11.733333587646484
# Rollout 1950 started
# Evaluation: Rollout: 1960, Avg rewards sum: 15.266666412353516
# Evaluation: Rollout: 1980, Avg rewards sum: 14.100000381469727
# Rollout 2000 started
# Evaluation: Rollout: 2000, Avg rewards sum: 15.699999809265137
